# %% [markdown]
# ## Урок № 2

# %% [markdown]
# ### Задание № 1.
# Вероятность того, что стрелок попадет в мишень, выстрелив один раз, равна 0.8. Стрелок выстрелил 100 раз. Найдите вероятность того, что стрелок попадет в цель ровно 85 раз.

# %% [markdown]
# **Ответ:**

# %% [markdown]
# Один "эксперимент" это 100 подряд выстрелов стрелка. При этом случайная величина имеет биномиальный закон распределения.

# %%
from math import factorial
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def combinations(n, k):
    return factorial(n) / (factorial(k) * factorial(n - k))

# %%
p1 = combinations(100, 85) * 0.8**85 * 0.2**15
p1
# Out:
# 0.048061793700746556

# %%
n = 100
plt.figure(figsize=(10, 7))
plt.title('Биномиальное распределение')
plt.xlabel('k')
plt.ylabel('P')
plt.scatter(range(n+1), [combinations(100, k) * 0.8**k * 0.2**(100-k) for k in range(n+1)])
plt.plot([85 for _ in range(n+1)], [combinations(100, k) * 0.8**k * 0.2**(100-k) for k in range(n+1)])
plt.plot([_ for _ in range(n+1)], [combinations(100, 85) * 0.8**85 * 0.2**(100-85) for _ in range(n+1)])
plt.show()

# %% [markdown]
# ### Задание № 2.
# Вероятность того, что лампочка перегорит в течение первого дня эксплуатации, равна 0.0004. В жилом комплексе после ремонта в один день включили 5000 новых лампочек. Какова вероятность, что ни одна из них не перегорит в первый день? Какова вероятность, что перегорят ровно две?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# Случайная величина имеет закон распределения Пуассона.

# %%
from math import exp

# %%
lambda_ = 5000 * 0.0004
lambda_
# Out:
# 2.0

# %%
m = 0
p2_1 = lambda_**m * exp(-lambda_) / factorial(m)
p2_1
# Out:
# 0.1353352832366127

# %%
m = 2
p2_2 = lambda_**m * exp(-lambda_) / factorial(m)
p2_2
# Out:
# 0.2706705664732254

# %%
n = 100
plt.figure(figsize=(10, 7))
plt.title('Распределение Пуассона')
plt.xlabel('m')
plt.ylabel('P')
plt.plot(range(n+1), [lambda_**m * exp(-lambda_) / factorial(m) for m in range(n+1)])
plt.show()

# %% [markdown]
# ### Задание № 3.
# Монету подбросили 144 раза. Какова вероятность, что орел выпадет ровно 70 раз?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# Один "эксперимент" это 144 подряд подбрасываний монеты. При этом случайная величина имеет биномиальный закон распределения.

# %%
def combinations(n, k):
    return factorial(n) / (factorial(k) * factorial(n - k))

# %%
p3 = combinations(144, 70) * 0.5**70 * 0.5**74
p3
# Out:
# 0.06281178035144776

# %%
n = 144
plt.figure(figsize=(10, 7))
plt.title('Биномиальное распределение')
plt.xlabel('k')
plt.ylabel('P')
plt.scatter(range(n+1), [combinations(144, k) * 0.5**k * 0.5**(144-k) for k in range(n+1)])
plt.plot([70 for _ in range(n+1)], [combinations(144, k) * 0.5**k * 0.5**(144-k) for k in range(n+1)])
plt.plot([_ for _ in range(n+1)], [combinations(144, 70) * 0.5**70 * 0.5**74 for _ in range(n+1)])
plt.show()

# %% [markdown]
# ### Задание № 4.
# В первом ящике находится 10 мячей, из которых 7 - белые. Во втором ящике - 11 мячей, из которых 9 белых. Из каждого ящика вытаскивают случайным образом по два мяча. Какова вероятность того, что все мячи белые? Какова вероятность того, что ровно два мяча белые? Какова вероятность того, что хотя бы один мяч белый?

# %% [markdown]
# **Ответ:**

# %%
p4_1 = 7/10 * 6/9 * 9/11 * 8/10
p4_1
# Out:
# 0.3054545454545454

# %%
# Итоговая вероятность складывается из вероятностей шести вариантов выпадения двух белых шаров - когда оба взяты только из
# первого ящика, затем только из второго ящика и четыре варианта когда взято по одному из каждого ящика
p4_2 = 7/10 * 6/9 * 2/11 * 1/10 + 3/10 * 2/9 * 9/11 * 8/10 + 4 * (7/10 * 3/9 * 9/11 * 2/10)
p4_2
# Out:
# 0.20484848484848484

# %%
# Находим вероятность того, что ни один белый мяч не выпал и вычтем полученное значение из "1"
p4_3 = 1 - 3/10 * 2/9 * 2/11 * 1/10
p4_3
# Out:
# 0.9987878787878788
